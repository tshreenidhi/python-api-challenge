# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

#set the units of measurement
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | colonia
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | papatowai
# Processing Record 7 of Set 1 | dunedin
# Processing Record 8 of Set 1 | enewetak
# Processing Record 9 of Set 1 | tolanaro
# Processing Record 10 of Set 1 | papao
# Processing Record 11 of Set 1 | hawaiian paradise park
# Processing Record 12 of Set 1 | stanley
# Processing Record 13 of Set 1 | kardla
# Processing Record 14 of Set 1 | hassi messaoud
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | sandakan
# Processing Record 17 of Set 1 | sao goncalo do sapucai
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | west island
# Processing Record 23 of Set 1 | tazacorte
# Processing Record 24 of Set 1 | pandan
# Processing Record 25 of Set 1 | penzance
# Processing Record 26 of Set 1 | prey veng
# Processing Record 27 of Set 1 | ulsteinvik
# Processing Record 28 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | margaret river
# Processing Record 31 of Set 1 | lensk
# Processing Record 32 of Set 1 | hotan
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | qaqortoq
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | udachny
# Processing Record 37 of Set 1 | kayangel
# Processing Record 38 of Set 1 | aasiaat
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | kamaishi
# Processing Record 42 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 1 | touros
# Processing Record 44 of Set 1 | gorom-gorom
# Processing Record 45 of Set 1 | invercargill
# Processing Record 46 of Set 1 | tura
# Processing Record 47 of Set 1 | borjomi
# Processing Record 48 of Set 1 | sinabang
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | thunder bay
# Processing Record 1 of Set 2 | vorgashor
# Processing Record 2 of Set 2 | simpang
# Processing Record 3 of Set 2 | lata
# Processing Record 4 of Set 2 | ceerigaabo
# Processing Record 5 of Set 2 | bogalusa
# Processing Record 6 of Set 2 | ghat
# Processing Record 7 of Set 2 | weno
# Processing Record 8 of Set 2 | syas'stroy
# Processing Record 9 of Set 2 | utrik
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | isafjordur
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | maubara
# City not found. Skipping...
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | whitehorse
# Processing Record 16 of Set 2 | nieves
# Processing Record 17 of Set 2 | champua
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | barranca
# Processing Record 20 of Set 2 | durres
# Processing Record 21 of Set 2 | college
# Processing Record 22 of Set 2 | torres
# Processing Record 23 of Set 2 | obubra
# Processing Record 24 of Set 2 | el calafate
# Processing Record 25 of Set 2 | kirakira
# Processing Record 26 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 2 | wanning
# Processing Record 28 of Set 2 | adamstown
# Processing Record 29 of Set 2 | afaahiti
# Processing Record 30 of Set 2 | badger
# Processing Record 31 of Set 2 | akureyri
# Processing Record 32 of Set 2 | port douglas
# Processing Record 33 of Set 2 | al bawiti
# Processing Record 34 of Set 2 | flying fish cove
# Processing Record 35 of Set 2 | minot air force base
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | lupane
# Processing Record 38 of Set 2 | cole harbour
# Processing Record 39 of Set 2 | la'ie
# Processing Record 40 of Set 2 | bikenibeu village
# Processing Record 41 of Set 2 | egilsstadir
# Processing Record 42 of Set 2 | port mathurin
# Processing Record 43 of Set 2 | saipan
# Processing Record 44 of Set 2 | harper
# Processing Record 45 of Set 2 | ikedacho
# Processing Record 46 of Set 2 | renqiu
# Processing Record 47 of Set 2 | al ghayzah
# Processing Record 48 of Set 2 | nar'yan-mar
# Processing Record 49 of Set 2 | avarua
# Processing Record 0 of Set 3 | yetkul'
# Processing Record 1 of Set 3 | oxelosund
# Processing Record 2 of Set 3 | lorengau
# Processing Record 3 of Set 3 | blackmans bay
# Processing Record 4 of Set 3 | bocanda
# Processing Record 5 of Set 3 | la passe
# Processing Record 6 of Set 3 | broken hill
# Processing Record 7 of Set 3 | guaratinga
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | wailua homesteads
# Processing Record 10 of Set 3 | santa ana
# Processing Record 11 of Set 3 | kolonia town
# Processing Record 12 of Set 3 | chibougamau
# Processing Record 13 of Set 3 | westport
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | muisne
# City not found. Skipping...
# Processing Record 16 of Set 3 | ghadamis
# Processing Record 17 of Set 3 | marathon
# Processing Record 18 of Set 3 | ust-nera
# Processing Record 19 of Set 3 | saint-francois
# Processing Record 20 of Set 3 | kipushi
# Processing Record 21 of Set 3 | atafu village
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | pokhara
# Processing Record 24 of Set 3 | kidal
# Processing Record 25 of Set 3 | kantharalak
# Processing Record 26 of Set 3 | la ronge
# Processing Record 27 of Set 3 | prainha
# Processing Record 28 of Set 3 | ta`u
# Processing Record 29 of Set 3 | abepura
# Processing Record 30 of Set 3 | ndele
# Processing Record 31 of Set 3 | hwange
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | kununurra
# Processing Record 35 of Set 3 | kattivakkam
# Processing Record 36 of Set 3 | capo d'orlando
# Processing Record 37 of Set 3 | bondoukou
# Processing Record 38 of Set 3 | uturoa
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 3 | st. john's
# Processing Record 42 of Set 3 | rocha
# Processing Record 43 of Set 3 | balkashino
# Processing Record 44 of Set 3 | bamboo flat
# Processing Record 45 of Set 3 | guangming
# Processing Record 46 of Set 3 | kittila
# Processing Record 47 of Set 3 | zhengzhou
# Processing Record 48 of Set 3 | riohacha
# Processing Record 49 of Set 3 | itaituba
# Processing Record 0 of Set 4 | iskateley
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | kuta
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | happy valley-goose bay
# Processing Record 7 of Set 4 | midelt
# Processing Record 8 of Set 4 | smara
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | lihue
# Processing Record 11 of Set 4 | machico
# Processing Record 12 of Set 4 | ola
# Processing Record 13 of Set 4 | rafraf
# Processing Record 14 of Set 4 | mitsamiouli
# Processing Record 15 of Set 4 | sadjoavato
# City not found. Skipping...
# Processing Record 16 of Set 4 | barcelos
# Processing Record 17 of Set 4 | chateauneuf-sur-loire
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | al hawatah
# Processing Record 20 of Set 4 | anna regina
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | moree
# Processing Record 23 of Set 4 | beloyarskiy
# Processing Record 24 of Set 4 | anadyr
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | dongfeng
# Processing Record 27 of Set 4 | faya-largeau
# Processing Record 28 of Set 4 | aden
# Processing Record 29 of Set 4 | feijo
# Processing Record 30 of Set 4 | oamaru
# Processing Record 31 of Set 4 | kharp
# Processing Record 32 of Set 4 | lyudinovo
# Processing Record 33 of Set 4 | raduzhny
# Processing Record 34 of Set 4 | yigo village
# Processing Record 35 of Set 4 | castillos
# Processing Record 36 of Set 4 | horta
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | gadzhiyevo
# Processing Record 39 of Set 4 | kalianget
# Processing Record 40 of Set 4 | burang
# Processing Record 41 of Set 4 | brokopondo
# Processing Record 42 of Set 4 | salpazari
# Processing Record 43 of Set 4 | hola
# Processing Record 44 of Set 4 | revda
# Processing Record 45 of Set 4 | keflavik
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | mombetsu
# Processing Record 48 of Set 4 | mejit
# Processing Record 49 of Set 4 | elliot lake
# Processing Record 0 of Set 5 | al lagowa
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | bardai
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | alta sierra
# Processing Record 5 of Set 5 | praia da vitoria
# Processing Record 6 of Set 5 | shangri-la
# City not found. Skipping...
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | mirnyy
# Processing Record 9 of Set 5 | klyuchi
# Processing Record 10 of Set 5 | abagur
# Processing Record 11 of Set 5 | fale old settlement
# Processing Record 12 of Set 5 | mount isa
# Processing Record 13 of Set 5 | tinajo
# Processing Record 14 of Set 5 | tofol
# Processing Record 15 of Set 5 | guiuan
# Processing Record 16 of Set 5 | 'izbat al burj
# City not found. Skipping...
# Processing Record 17 of Set 5 | tazovsky
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | meadow lake
# Processing Record 20 of Set 5 | susuman
# Processing Record 21 of Set 5 | zharkent
# Processing Record 22 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 5 | vadso
# Processing Record 24 of Set 5 | brainerd
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | menaka
# Processing Record 27 of Set 5 | chonchi
# Processing Record 28 of Set 5 | bafq
# Processing Record 29 of Set 5 | jamestown
# Processing Record 30 of Set 5 | guatrache
# Processing Record 31 of Set 5 | patterson
# Processing Record 32 of Set 5 | pampa
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | sambava
# Processing Record 35 of Set 5 | grafton
# Processing Record 36 of Set 5 | altai
# Processing Record 37 of Set 5 | saint-christol-les-ales
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | ocean pointe
# City not found. Skipping...
# Processing Record 40 of Set 5 | kirsehir
# Processing Record 41 of Set 5 | hailun
# Processing Record 42 of Set 5 | erenhot
# Processing Record 43 of Set 5 | borshchiv
# Processing Record 44 of Set 5 | kharkhorin
# Processing Record 45 of Set 5 | agat village
# Processing Record 46 of Set 5 | hirara
# Processing Record 47 of Set 5 | miranda
# Processing Record 48 of Set 5 | hobbs
# Processing Record 49 of Set 5 | hammerfest
# Processing Record 0 of Set 6 | waingapu
# Processing Record 1 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 2 of Set 6 | massawa
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | lyozna
# Processing Record 5 of Set 6 | chiang rai
# Processing Record 6 of Set 6 | oum hadjer
# Processing Record 7 of Set 6 | saudarkrokur
# Processing Record 8 of Set 6 | northam
# Processing Record 9 of Set 6 | san antonio de pale
# Processing Record 10 of Set 6 | buka
# Processing Record 11 of Set 6 | luchenza
# Processing Record 12 of Set 6 | tayu
# Processing Record 13 of Set 6 | ventspils
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 16 of Set 6 | san lawrenz
# Processing Record 17 of Set 6 | iquique
# Processing Record 18 of Set 6 | pacific grove
# Processing Record 19 of Set 6 | lethem
# Processing Record 20 of Set 6 | newman
# Processing Record 21 of Set 6 | nova sintra
# Processing Record 22 of Set 6 | kindu
# Processing Record 23 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 24 of Set 6 | luziania
# Processing Record 25 of Set 6 | kerikeri
# Processing Record 26 of Set 6 | inskoy
# Processing Record 27 of Set 6 | konarka
# Processing Record 28 of Set 6 | bel ombre
# Processing Record 29 of Set 6 | daru
# Processing Record 30 of Set 6 | howrah
# Processing Record 31 of Set 6 | bubaque
# Processing Record 32 of Set 6 | koulamoutou
# Processing Record 33 of Set 6 | okhotsk
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | juhaynah
# Processing Record 36 of Set 6 | omdurman
# Processing Record 37 of Set 6 | kapa'a
# Processing Record 38 of Set 6 | kindia
# Processing Record 39 of Set 6 | molochnoye
# Processing Record 40 of Set 6 | ilulissat
# Processing Record 41 of Set 6 | hede
# Processing Record 42 of Set 6 | wajir
# Processing Record 43 of Set 6 | antsiranana
# Processing Record 44 of Set 6 | huangnihe
# Processing Record 45 of Set 6 | sredets
# Processing Record 46 of Set 6 | khandyga
# Processing Record 47 of Set 6 | gazli
# Processing Record 48 of Set 6 | smithers
# Processing Record 49 of Set 6 | yeniseysk
# Processing Record 0 of Set 7 | aba
# Processing Record 1 of Set 7 | karratha
# Processing Record 2 of Set 7 | punta arenas
# Processing Record 3 of Set 7 | ust'-ordynskiy
# Processing Record 4 of Set 7 | vilhena
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | xylokastro
# Processing Record 7 of Set 7 | fenoarivo atsinanana
# Processing Record 8 of Set 7 | morehead city
# Processing Record 9 of Set 7 | porbandar
# Processing Record 10 of Set 7 | amursk
# Processing Record 11 of Set 7 | obama
# Processing Record 12 of Set 7 | jaguarari
# Processing Record 13 of Set 7 | callao
# Processing Record 14 of Set 7 | kingston
# Processing Record 15 of Set 7 | ellsworth
# Processing Record 16 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 7 | mil'kovo
# Processing Record 18 of Set 7 | mawlaik
# Processing Record 19 of Set 7 | manokwari
# Processing Record 20 of Set 7 | aleg
# Processing Record 21 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 7 | bodaybo
# Processing Record 23 of Set 7 | tommot
# Processing Record 24 of Set 7 | clearwater
# Processing Record 25 of Set 7 | elista
# Processing Record 26 of Set 7 | al qubbah
# Processing Record 27 of Set 7 | kristiansund
# Processing Record 28 of Set 7 | luena
# Processing Record 29 of Set 7 | ekibastuz
# Processing Record 30 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 31 of Set 7 | samfya
# Processing Record 32 of Set 7 | opuwo
# Processing Record 33 of Set 7 | lompoc
# Processing Record 34 of Set 7 | hue
# Processing Record 35 of Set 7 | tongren
# Processing Record 36 of Set 7 | worland
# Processing Record 37 of Set 7 | nova olimpia
# Processing Record 38 of Set 7 | trujillo
# Processing Record 39 of Set 7 | kalmunai
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 42 of Set 7 | san giovanni valdarno
# Processing Record 43 of Set 7 | ghanzi
# Processing Record 44 of Set 7 | jackson
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | shinkafi
# Processing Record 47 of Set 7 | vinales
# Processing Record 48 of Set 7 | ituiutaba
# Processing Record 49 of Set 7 | tongliao
# Processing Record 0 of Set 8 | mukah
# City not found. Skipping...
# Processing Record 1 of Set 8 | magadan
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | bechar
# Processing Record 4 of Set 8 | waddan
# Processing Record 5 of Set 8 | coronel suarez
# Processing Record 6 of Set 8 | puerto baquerizo moreno
# Processing Record 7 of Set 8 | bartica
# Processing Record 8 of Set 8 | strelka
# Processing Record 9 of Set 8 | betio village
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | cedeira
# Processing Record 12 of Set 8 | saldanha
# Processing Record 13 of Set 8 | mpika
# Processing Record 14 of Set 8 | inirida
# Processing Record 15 of Set 8 | nizhniy lomov
# Processing Record 16 of Set 8 | nikolayevsk-on-amure
# Processing Record 17 of Set 8 | hermanus
# Processing Record 18 of Set 8 | guozhen
# Processing Record 19 of Set 8 | suva
# Processing Record 20 of Set 8 | argo
# Processing Record 21 of Set 8 | qarauyl
# Processing Record 22 of Set 8 | arica
# Processing Record 23 of Set 8 | mount pearl
# Processing Record 24 of Set 8 | veraval
# Processing Record 25 of Set 8 | taroa
# Processing Record 26 of Set 8 | carqueiranne
# Processing Record 27 of Set 8 | alta
# Processing Record 28 of Set 8 | awjilah
# Processing Record 29 of Set 8 | vila do maio
# Processing Record 30 of Set 8 | tangalle
# Processing Record 31 of Set 8 | road town
# Processing Record 32 of Set 8 | nelson bay
# Processing Record 33 of Set 8 | constantia
# Processing Record 34 of Set 8 | usogorsk
# Processing Record 35 of Set 8 | riosucio
# Processing Record 36 of Set 8 | mingyue
# Processing Record 37 of Set 8 | kiknur
# Processing Record 38 of Set 8 | oranjemund
# Processing Record 39 of Set 8 | fauske
# Processing Record 40 of Set 8 | krompachy
# Processing Record 41 of Set 8 | yaren
# Processing Record 42 of Set 8 | jayapura
# Processing Record 43 of Set 8 | hakha
# Processing Record 44 of Set 8 | tual
# Processing Record 45 of Set 8 | hakui
# Processing Record 46 of Set 8 | vilyuchinsk
# Processing Record 47 of Set 8 | hardys memories of africa
# City not found. Skipping...
# Processing Record 48 of Set 8 | payson
# Processing Record 49 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 0 of Set 9 | mykolaiv
# Processing Record 1 of Set 9 | margate
# Processing Record 2 of Set 9 | bamyan
# Processing Record 3 of Set 9 | spring creek
# Processing Record 4 of Set 9 | kimbe
# Processing Record 5 of Set 9 | vilyuysk
# Processing Record 6 of Set 9 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 7 of Set 9 | sirte
# Processing Record 8 of Set 9 | redmond
# Processing Record 9 of Set 9 | nuuk
# Processing Record 10 of Set 9 | taro
# Processing Record 11 of Set 9 | dauphin
# Processing Record 12 of Set 9 | cannonvale
# Processing Record 13 of Set 9 | concepcion
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | situbondo
# Processing Record 16 of Set 9 | gizo
# Processing Record 17 of Set 9 | omuthiya
# City not found. Skipping...
# Processing Record 18 of Set 9 | mek'ele
# Processing Record 19 of Set 9 | somanda
# Processing Record 20 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | queenstown
# Processing Record 23 of Set 9 | kourou
# Processing Record 24 of Set 9 | estevan
# Processing Record 25 of Set 9 | alo
# Processing Record 26 of Set 9 | chemolgan
# Processing Record 27 of Set 9 | kavieng
# Processing Record 28 of Set 9 | itapage
# Processing Record 29 of Set 9 | tisul'
# Processing Record 30 of Set 9 | minas de marcona
# Processing Record 31 of Set 9 | mtimbira
# Processing Record 32 of Set 9 | n'zeto
# Processing Record 33 of Set 9 | coahuayana de hidalgo
# Processing Record 34 of Set 9 | viedma
# Processing Record 35 of Set 9 | anori
# Processing Record 36 of Set 9 | san fernando
# Processing Record 37 of Set 9 | wotho
# Processing Record 38 of Set 9 | youkounkoun
# Processing Record 39 of Set 9 | olinda
# Processing Record 40 of Set 9 | gisborne
# Processing Record 41 of Set 9 | union
# Processing Record 42 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 43 of Set 9 | kapuskasing
# Processing Record 44 of Set 9 | bindlach
# Processing Record 45 of Set 9 | liezen
# Processing Record 46 of Set 9 | powell river
# Processing Record 47 of Set 9 | sitka
# Processing Record 48 of Set 9 | hanover
# Processing Record 49 of Set 9 | carutapera
# Processing Record 0 of Set 10 | garhwa
# Processing Record 1 of Set 10 | mikhaylovsk
# Processing Record 2 of Set 10 | zuidhorn
# Processing Record 3 of Set 10 | minas de matahambre
# City not found. Skipping...
# Processing Record 4 of Set 10 | sitia
# Processing Record 5 of Set 10 | batam
# City not found. Skipping...
# Processing Record 6 of Set 10 | pasuquin
# Processing Record 7 of Set 10 | anloga
# Processing Record 8 of Set 10 | hadibu
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | haiku-pauwela
# Processing Record 11 of Set 10 | meadow lakes
# Processing Record 12 of Set 10 | san-pedro
# Processing Record 13 of Set 10 | pasni
# Processing Record 14 of Set 10 | luganville
# Processing Record 15 of Set 10 | mandalgovi
# Processing Record 16 of Set 10 | bandarbeyla
# Processing Record 17 of Set 10 | novaya igirma
# Processing Record 18 of Set 10 | osakarovka
# Processing Record 19 of Set 10 | reggane
# Processing Record 20 of Set 10 | peniche
# Processing Record 21 of Set 10 | maloye ganyushkino
# Processing Record 22 of Set 10 | prince rupert
# Processing Record 23 of Set 10 | olyokminsk
# Processing Record 24 of Set 10 | gangtok
# Processing Record 25 of Set 10 | fonadhoo
# City not found. Skipping...
# Processing Record 26 of Set 10 | basoko
# Processing Record 27 of Set 10 | eirunepe
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | ouani
# Processing Record 30 of Set 10 | al qusayr
# Processing Record 31 of Set 10 | kosh-agach
# Processing Record 32 of Set 10 | aflou
# Processing Record 33 of Set 10 | bulungu
# Processing Record 34 of Set 10 | bay harbor
# Processing Record 35 of Set 10 | fortaleza
# Processing Record 36 of Set 10 | polyarnyy
# Processing Record 37 of Set 10 | arraial do cabo
# Processing Record 38 of Set 10 | alliance
# Processing Record 39 of Set 10 | ketchikan
# Processing Record 40 of Set 10 | conde
# Processing Record 41 of Set 10 | villa presidente frei, nunoa, santiago, chile
# City not found. Skipping...
# Processing Record 42 of Set 10 | san fernando del valle de catamarca
# Processing Record 43 of Set 10 | katsuura
# Processing Record 44 of Set 10 | neuburg an der donau
# Processing Record 45 of Set 10 | port saint john's
# Processing Record 46 of Set 10 | pamandzi
# Processing Record 47 of Set 10 | ebon
# Processing Record 48 of Set 10 | gurupi
# Processing Record 49 of Set 10 | noumea
# Processing Record 0 of Set 11 | alexander city
# Processing Record 1 of Set 11 | le moule
# Processing Record 2 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 3 of Set 11 | brookings
# Processing Record 4 of Set 11 | rikaze
# Processing Record 5 of Set 11 | tobelo
# Processing Record 6 of Set 11 | pangody
# Processing Record 7 of Set 11 | aripuana
# Processing Record 8 of Set 11 | kas
# Processing Record 9 of Set 11 | fort bragg
# Processing Record 10 of Set 11 | l'govskiy
# Processing Record 11 of Set 11 | majene
# Processing Record 12 of Set 11 | dubbo
# Processing Record 13 of Set 11 | desnogorsk
# Processing Record 14 of Set 11 | astrakhan
# Processing Record 15 of Set 11 | boyolangu
# Processing Record 16 of Set 11 | kailua-kona
# Processing Record 17 of Set 11 | neiafu
# Processing Record 18 of Set 11 | port macquarie
# Processing Record 19 of Set 11 | saint-philippe
# Processing Record 20 of Set 11 | dawson creek
# Processing Record 21 of Set 11 | vila franca do campo
# Processing Record 22 of Set 11 | ishimbay
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | ad dabbah
# Processing Record 25 of Set 11 | kopoky
# City not found. Skipping...
# Processing Record 26 of Set 11 | cananeia
# Processing Record 27 of Set 11 | rattvik
# City not found. Skipping...
# Processing Record 28 of Set 11 | kyabe
# Processing Record 29 of Set 11 | sabang
# Processing Record 30 of Set 11 | linden
# Processing Record 31 of Set 11 | borogontsy
# Processing Record 32 of Set 11 | bardsir
# Processing Record 33 of Set 11 | periyapattinam
# City not found. Skipping...
# Processing Record 34 of Set 11 | sao vicente
# Processing Record 35 of Set 11 | nieuw amsterdam
# Processing Record 36 of Set 11 | sterling
# Processing Record 37 of Set 11 | kisolon
# Processing Record 38 of Set 11 | kiama
# Processing Record 39 of Set 11 | ujae
# Processing Record 40 of Set 11 | tsiombe
# Processing Record 41 of Set 11 | tallahassee
# Processing Record 42 of Set 11 | muana
# Processing Record 43 of Set 11 | crane
# Processing Record 44 of Set 11 | klaksvik
# Processing Record 45 of Set 11 | puerto aysen
# Processing Record 46 of Set 11 | pokotylivka
# Processing Record 47 of Set 11 | aginskoye
# Processing Record 48 of Set 11 | aver-o-mar
# Processing Record 49 of Set 11 | rongelap
# Processing Record 0 of Set 12 | tuensang
# Processing Record 1 of Set 12 | holualoa
# Processing Record 2 of Set 12 | nagqu
# Processing Record 3 of Set 12 | san julian
# Processing Record 4 of Set 12 | brisas de zicatela
# Processing Record 5 of Set 12 | plettenberg bay
# Processing Record 6 of Set 12 | dwarka
# Processing Record 7 of Set 12 | old orchard beach
# Processing Record 8 of Set 12 | bukama
# Processing Record 9 of Set 12 | kajaani
# Processing Record 10 of Set 12 | shache
# Processing Record 11 of Set 12 | tshikapa
# Processing Record 12 of Set 12 | bayanhongor
# Processing Record 13 of Set 12 | mukalla
# Processing Record 14 of Set 12 | kone
# Processing Record 15 of Set 12 | richards bay
# Processing Record 16 of Set 12 | gargzdai
# Processing Record 17 of Set 12 | vrangel'
# Processing Record 18 of Set 12 | palangkaraya
# Processing Record 19 of Set 12 | dali
# Processing Record 20 of Set 12 | labytnangi
# Processing Record 21 of Set 12 | camocim
# Processing Record 22 of Set 12 | kuqa
# Processing Record 23 of Set 12 | chefchaouene
# Processing Record 24 of Set 12 | kualakapuas
# Processing Record 25 of Set 12 | san miguel
# Processing Record 26 of Set 12 | aioun
# Processing Record 27 of Set 12 | kill devil hills
# Processing Record 28 of Set 12 | angra dos reis
# Processing Record 29 of Set 12 | guiyang
# Processing Record 30 of Set 12 | jiuquan
# Processing Record 31 of Set 12 | aykhal
# Processing Record 32 of Set 12 | villa gesell
# Processing Record 33 of Set 12 | arno
# Processing Record 34 of Set 12 | port-vila
# Processing Record 35 of Set 12 | lingyuan
# Processing Record 36 of Set 12 | forster
# Processing Record 37 of Set 12 | lazaro cardenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      colonia  50.9333    6.9500      3.31        92         100        3.60
# 1     waitangi -43.9535 -176.5597     13.23        92           9        0.89
# 2    hithadhoo  -0.6000   73.0833     27.44        79         100        6.11
# 3  olonkinbyen  70.9221   -8.7187     -6.18        85          98        5.12
# 4       albany  42.6001  -73.9662      0.57        72         100        0.89
#
#   Country        Date
# 0      DE  1704566238
# 1      NZ  1704566341
# 2      MV  1704566342
# 3      SJ  1704566343
# 4      US  1704566217

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            colonia  50.9333    6.9500      3.31        92         100
# 1           waitangi -43.9535 -176.5597     13.23        92           9
# 2          hithadhoo  -0.6000   73.0833     27.44        79         100
# 3        olonkinbyen  70.9221   -8.7187     -6.18        85          98
# 4             albany  42.6001  -73.9662      0.57        72         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      DE  1704566238
# 1              0.89      NZ  1704566341
# 2              6.11      MV  1704566342
# 3              5.12      SJ  1704566343
# 4              0.89      US  1704566217

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%) ")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       colonia  50.9333    6.9500      3.31        92
# 3                   olonkinbyen  70.9221   -8.7187     -6.18        85
# 4                        albany  42.6001  -73.9662      0.57        72
# 7                      enewetak  11.3474  162.3373     26.17        66
# 10       hawaiian paradise park  19.5933 -154.9731     21.13        98
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.60      DE  1704566238
# 3                98        5.12      SJ  1704566343
# 4               100        0.89      US  1704566217
# 7                15        8.06      MH  1704566345
# 10              100        1.54      US  1704566346

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         waitangi -43.9535 -176.5597     13.23        92           9
# 2        hithadhoo  -0.6000   73.0833     27.44        79         100
# 5        papatowai -46.5619  169.4708     13.63        82         100
# 6          dunedin -45.8742  170.5036     12.67        91          89
# 8         tolanaro -25.0319   46.9987     26.04        78          75
#
#          Wind Speed Country        Date
# City_ID
# 1              0.89      NZ  1704566341
# 2              6.11      MV  1704566342
# 5              3.81      NZ  1704566202
# 6              1.79      NZ  1704566327
# 8              9.26      MG  1704565771

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The graph shows the negative relation between temperature and latitude")
print("In the northern hemisphere, the distance from the equator increases as the latitude increases")
print("The temperature decreases as we move away from the equator,")
# Out:
# The r-value is -0.8761172082237259
# -----------------------------------
# Observations about linear relationship:
# The graph shows the negative relation between temperature and latitude
# In the northern hemisphere, the distance from the equator increases as the latitude increases
# The temperature decreases as we move away from the equator,

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Below are the observations on the graph:")
print("We have a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("The temperature generally increases as we move closer to the equator, ")
# Out:
# The r-value is 0.6545503110941876
# -----------------------------------
# Below are the observations on the graph:
# We have a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# The temperature generally increases as we move closer to the equator,

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("We see a slight positive corelation between humidity and latitude.")
print("Humidity increases as the latitude increases.")
# Out:
# The r-value is 0.5098834565920505
# -----------------------------------
# Observations about linear relationship:
# We see a slight positive corelation between humidity and latitude.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("We observe a slightly positive corelation.")
# Out:
# The r-value is 0.24919785795184513
# -----------------------------------
# Observations about linear relationship:
# We observe a slightly positive corelation.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("Since the r value is less than 0.5, there does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.24098302590956966
# -----------------------------------
# Observations about linear relationship:
# Since the r value is less than 0.5, there does not appear to be a coorelation between latitude and cloudiness.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("Since the r value is very low, there does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.20171834889338675
# -----------------------------------
# Observations about linear relationship:
# Since the r value is very low, there does not appear to be a coorelation between latitude and cloudiness.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.12855380783697018
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.2600703902396841
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
